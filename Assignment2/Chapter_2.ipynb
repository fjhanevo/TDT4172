# %% [markdown]
# # 🌟 Assignment 2. Operation "AI GeoGuessr"
#
# ### Deadline: Friday, October 24, 2025, 11:59:00 PM CET (GMT +2)
#
# ## 🎯 Mission Overview
#
# The operation consists of two independent missions. Similar to the previous operation, students are required to solve the tasks by achieving the required score and answering the follow-up questions.
#
# ## 🧪 Neural Networks and Unsupervised Learning
#
# 1. **Mission 2.1 (Supervised Learning)**:
#    - Solve a supervised learning problem using a multilayer perceptron (MLP).
#
# 2. **Mission 2.2 (Unsupervised Learning)**:
#    - Given an unlabeled dataset, your task is to cluster similar data points and achieve 100% clustering accuracy. You will not have access to the true labels, but you can verify your cluster assignments using the Kaggle competition provided.
#
# ## 📝 Delivery Format (Blackboard)
#
# Please submit **two files**:
# 1. The completed Jupyter notebook.
# 2. The solution for the second dataset as a CSV file with two `int` columns: `['ID', 'cluster']`.
#
# ## Kaggle details
# - Invitation link: https://www.kaggle.com/t/dfb72837bdb346449768b8f6ce50b6dc
# - Kaggle is a popular platform for data science competitions.
# - It allows us to create a Private competition where you can submit your solutions and verify whether you are thinking in the right direction.
# - The results of the competition is visible only to the competition participants.
# - We will not grade the submissions on Kaggle, we set it up to let you check your clustering.
# - You still have to deliver the `.csv` file of the solution and the complete `.ipynb` notebook with discussions and solution code.
#
# > Good luck, comrade!

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # 🧠 Mission 2.1: Decoding SkyNet's Neural Encryption **(using Neural Networks)**
#
# ### 🌐 The Discovery
# The dataset consists of the same "Synapse Cipher" data from Assignment 1.
#
# ### 🎯 Your Mission
# 1. Implement a multilayer perceptron (MLP) using one of the following frameworks: Keras, PyTorch, or TensorFlow.
# 2. Solve the non-linear problem without manual feature engineering.
# 3. Predict SkyNet's binary decisions (0 or 1) based on paired signals.
# 4. Improve performance by using techniques such as learning rate scheduling, selecting a good optimizer, and fine-tuning hyperparameters.
#
# > Note: There are no restrictions on the tricks you can use — Have fun :)
#
# ### 📊 Formal Requirements
# 1. **Implementation**:
#    - Develop a Neural Network using predefined functions/layers.
#    - Use one of the popular frameworks: Keras, PyTorch, or TensorFlow.
#    - Implement a manual learning rate scheduler with warmup and cosine decay.
#
# 2. **Performance**: Achieve at least **0.92** accuracy on the test set.
#
# 3. **Discussion**:
#    - How can you make sure the results are reproduable?
#    - Visualize the network's architecture and decision boundary.
#    - Which optimizer did you choose? Discuss the differences between SGD and Adam.
#    - Plot the learning rate curve. Did the learning rate scheduling improve performance? Why or why not?
#    - Conduct a simple ablation study of each architectural and optimization choice concerning test accuracy.

# %%
data = pd.read_csv('nn_data.csv')
train = data[data['split'] == 'train']
test = data[data['split'] == 'test']

# %%
# split the dataset 
X_train = train[["x0", "x1"]]
y_train = train["y"]

X_test= test[["x0", "x1"]]
y_test= test["y"]

# %%
plt.figure(figsize=(6, 4))
plt.scatter(train['x0'], train['x1'], c=train['y'], cmap='coolwarm')
plt.grid(True)
plt.xlabel('x0', fontsize=14)
plt.ylabel('x1', fontsize=14)
plt.title('x1 vs. x0', fontsize=16)
plt.colorbar()
plt.show()

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL']='3'
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam 
import random

# Ensure reproducibility by setting seeds
seed = 42
random.seed(seed)
np.random.seed(seed)
tf.keras.utils.set_random_seed(seed)
tf.config.experimental.enable_op_determinism()

# %% [markdown]
# #### Implementation using a Learning Rate Scheduler

# %%
from lr_schedule import LearningRateScheduler
nodes = 16

lr_schedule = LearningRateScheduler(
    lr_min=1e-5,
    lr_max=1e-2,
    warmup_steps=100,
    total_steps=500
)

optimizer = Adam(learning_rate=lr_schedule)

model = Sequential(
        [
            Dense(nodes, activation='relu', input_shape=(X_train.shape[1],)),
            Dense(nodes, activation='relu'),
            Dense(nodes, activation='relu'),
            Dense(1, activation='sigmoid')
        ]
    )

model.compile(
    optimizer=optimizer,
    loss='binary_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    X_train, y_train,
    epochs=20,
    batch_size=32,
    validation_data=(X_test,y_test),
)
# Out:
# Epoch 1/20
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.6560 - loss: 0.6725 - val_accuracy: 0.6980 - val_loss: 0.6593
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7600 - loss: 0.6335 - val_accuracy: 0.7920 - val_loss: 0.5946
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8660 - loss: 0.5487 - val_accuracy: 0.8480 - val_loss: 0.4825
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9020 - loss: 0.4228 - val_accuracy: 0.8900 - val_loss: 0.3626
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9220 - loss: 0.3332 - val_accuracy: 0.9000 - val_loss: 0.3308
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9180 - loss: 0.3140 - val_accuracy: 0.8880 - val_loss: 0.3360
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9200 - loss: 0.3064 - val_accuracy: 0.8940 - val_loss: 0.3263
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9220 - loss: 0.2959 - val_accuracy: 0.9020 - val_loss: 0.3128
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9260 - loss: 0.2902 - val_accuracy: 0.9140 - val_loss: 0.3062
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9200 - loss: 0.2862 - val_accuracy: 0.9160 - val_loss: 0.2996
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9220 - loss: 0.2787 - val_accuracy: 0.9160 - val_loss: 0.3000
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9280 - loss: 0.2700 - val_accuracy: 0.9100 - val_loss: 0.2992
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9380 - loss: 0.2612 - val_accuracy: 0.9100 - val_loss: 0.2952
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9340 - loss: 0.2545 - val_accuracy: 0.9100 - val_loss: 0.2928
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9400 - loss: 0.2481 - val_accuracy: 0.9060 - val_loss: 0.2915
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9400 - loss: 0.2442 - val_accuracy: 0.9100 - val_loss: 0.2878
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9400 - loss: 0.2395 - val_accuracy: 0.9100 - val_loss: 0.2846
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9420 - loss: 0.2345 - val_accuracy: 0.9080 - val_loss: 0.2835
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9420 - loss: 0.2305 - val_accuracy: 0.9080 - val_loss: 0.2820
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9400 - loss: 0.2271 - val_accuracy: 0.9100 - val_loss: 0.2814

# %%
print(f"Validation accuracy: {history.history['val_accuracy'][-1]:.4}")
print(f"Validation loss: {history.history['val_loss'][-1]:.4}")
# Out:
# Validation accuracy: 0.91
# Validation loss: 0.2814

# %% [markdown]
# #### Hyperparameter tuning using GridSeachCV

# %%
from sklearn.model_selection import GridSearchCV 
from scikeras.wrappers import KerasClassifier

# %%
def create_model(lr_min, lr_max, warmup_steps, total_steps):
    lr_schedule = LearningRateScheduler(
        lr_min=lr_min, lr_max=lr_max,
        warmup_steps=warmup_steps,
        total_steps=total_steps
    )
    model = Sequential(
        [
            Dense(nodes, activation='relu', input_shape=(X_train.shape[1],)),
            Dense(nodes, activation='relu'),
            Dense(nodes, activation='relu'),
            Dense(1, activation='sigmoid')
        ]
    )
    optimizer = Adam(learning_rate=lr_schedule)

    model.compile(
        optimizer=optimizer,
        loss='binary_crossentropy',
        metrics=['accuracy']
    )

    return model

# %%
params = {
    'model__lr_min': [1e-4, 1e-3],
    'model__lr_max': [1e-2, 1e-1],
    'model__warmup_steps': [10, 100, 1000],
    'model__total_steps': [100, 1000],
    'epochs': [50, 100]
}

# Wrap the model to make it useable for GridSearchCV
model = KerasClassifier(
    model=create_model,
    verbose=0
)
    
grid= GridSearchCV(
    estimator=model,
    param_grid=params,
    n_jobs=-1,
    cv=3
)

grid_search = grid.fit(X_train, y_train)
# Out:
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7fb3b26404a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7f2d00c544a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7f7480c504a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7fcf80c644a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7f190cc684a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7f1b1be44040> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7f21d45604a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7f0b315644a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7f2d01553240> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7fb3b08bf240> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7fcf5065f240> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7f7481557240> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7f190c86f240> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7f1b1a0c32e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7f0b3116f240> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7f216a763240> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# ...
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
print(f"Best score: {grid_search.best_score_:.4}")
print(f"Best params: {grid_search.best_params_}")
# Out:
# Best score: 0.928
# Best params: {'epochs': 100, 'model__lr_max': 0.01, 'model__lr_min': 0.001, 'model__total_steps': 1000, 'model__warmup_steps': 100}

# %% [markdown]
# #### Train the model using the best parameters

# %%
best_params = grid_search.best_params_
lr_best = LearningRateScheduler(
    lr_min=best_params['model__lr_min'],
    lr_max=best_params['model__lr_max'],
    warmup_steps=best_params['model__warmup_steps'],
    total_steps=best_params['model__total_steps']
)

best_model = Sequential(
        [
            Dense(nodes, activation='relu', input_shape=(X_train.shape[1],)),
            Dense(nodes, activation='relu'),
            Dense(nodes, activation='relu'),
            Dense(1, activation='sigmoid')
        ]
    )
optimizer = Adam(learning_rate=lr_best)

best_model.compile(
        optimizer=optimizer,
        loss='binary_crossentropy',
        metrics=['accuracy']
)

best_history = best_model.fit(
    X_train, y_train,
    epochs=best_params['epochs'],
    batch_size=32,
    validation_data=(X_test, y_test)

)
# Out:
# Epoch 1/100
# /home/fredrik/MTKOM/H25/TDT4172/Assignment2/venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.6220 - loss: 0.6819 - val_accuracy: 0.8620 - val_loss: 0.6516
# Epoch 2/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8360 - loss: 0.6202 - val_accuracy: 0.8440 - val_loss: 0.5625
# Epoch 3/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8640 - loss: 0.5007 - val_accuracy: 0.8620 - val_loss: 0.4190
# Epoch 4/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8860 - loss: 0.3718 - val_accuracy: 0.8920 - val_loss: 0.3435
# Epoch 5/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9120 - loss: 0.3338 - val_accuracy: 0.8940 - val_loss: 0.3381
# Epoch 6/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9140 - loss: 0.3276 - val_accuracy: 0.9040 - val_loss: 0.3309
# Epoch 7/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9140 - loss: 0.3184 - val_accuracy: 0.9020 - val_loss: 0.3244
# Epoch 8/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9160 - loss: 0.3152 - val_accuracy: 0.8980 - val_loss: 0.3237
# Epoch 9/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9100 - loss: 0.3116 - val_accuracy: 0.9000 - val_loss: 0.3218
# Epoch 10/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8940 - loss: 0.3136 - val_accuracy: 0.9020 - val_loss: 0.3093
# Epoch 11/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8880 - loss: 0.3118 - val_accuracy: 0.9180 - val_loss: 0.3049
# Epoch 12/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9040 - loss: 0.2998 - val_accuracy: 0.9140 - val_loss: 0.3019
# Epoch 13/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9200 - loss: 0.2870 - val_accuracy: 0.9120 - val_loss: 0.3012
# Epoch 14/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9240 - loss: 0.2778 - val_accuracy: 0.9200 - val_loss: 0.2968
# Epoch 15/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9340 - loss: 0.2686 - val_accuracy: 0.9040 - val_loss: 0.2967
# Epoch 16/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9360 - loss: 0.2643 - val_accuracy: 0.9040 - val_loss: 0.2965
# Epoch 17/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9320 - loss: 0.2588 - val_accuracy: 0.8980 - val_loss: 0.2946
# Epoch 18/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9340 - loss: 0.2544 - val_accuracy: 0.9020 - val_loss: 0.2917
# Epoch 19/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9340 - loss: 0.2507 - val_accuracy: 0.8940 - val_loss: 0.2931
# Epoch 20/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9320 - loss: 0.2433 - val_accuracy: 0.9000 - val_loss: 0.2911
# Epoch 21/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9340 - loss: 0.2425 - val_accuracy: 0.8960 - val_loss: 0.2929
# Epoch 22/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9360 - loss: 0.2320 - val_accuracy: 0.9020 - val_loss: 0.2878
# Epoch 23/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9380 - loss: 0.2273 - val_accuracy: 0.9040 - val_loss: 0.2912
# Epoch 24/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9380 - loss: 0.2229 - val_accuracy: 0.9060 - val_loss: 0.2862
# Epoch 25/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9360 - loss: 0.2181 - val_accuracy: 0.9100 - val_loss: 0.2843
# Epoch 26/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9380 - loss: 0.2139 - val_accuracy: 0.9040 - val_loss: 0.2848
# Epoch 27/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9380 - loss: 0.2090 - val_accuracy: 0.9020 - val_loss: 0.2829
# Epoch 28/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9380 - loss: 0.2061 - val_accuracy: 0.9020 - val_loss: 0.2819
# Epoch 29/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9380 - loss: 0.2028 - val_accuracy: 0.9060 - val_loss: 0.2806
# Epoch 30/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9380 - loss: 0.2004 - val_accuracy: 0.8980 - val_loss: 0.2844
# Epoch 31/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9420 - loss: 0.1980 - val_accuracy: 0.9080 - val_loss: 0.2830
# Epoch 32/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9380 - loss: 0.1963 - val_accuracy: 0.9000 - val_loss: 0.2860
# Epoch 33/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9400 - loss: 0.1954 - val_accuracy: 0.9020 - val_loss: 0.2831
# Epoch 34/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9420 - loss: 0.1928 - val_accuracy: 0.9060 - val_loss: 0.2820
# Epoch 35/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9440 - loss: 0.1913 - val_accuracy: 0.9060 - val_loss: 0.2820
# Epoch 36/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9460 - loss: 0.1901 - val_accuracy: 0.9020 - val_loss: 0.2849
# Epoch 37/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9460 - loss: 0.1893 - val_accuracy: 0.9060 - val_loss: 0.2802
# Epoch 38/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9420 - loss: 0.1873 - val_accuracy: 0.9040 - val_loss: 0.2816
# Epoch 39/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9460 - loss: 0.1865 - val_accuracy: 0.9080 - val_loss: 0.2803
# Epoch 40/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9460 - loss: 0.1854 - val_accuracy: 0.9060 - val_loss: 0.2812
# Epoch 41/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9460 - loss: 0.1840 - val_accuracy: 0.9080 - val_loss: 0.2771
# Epoch 42/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9460 - loss: 0.1830 - val_accuracy: 0.9100 - val_loss: 0.2803
# Epoch 43/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9460 - loss: 0.1820 - val_accuracy: 0.9080 - val_loss: 0.2789
# Epoch 44/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9460 - loss: 0.1808 - val_accuracy: 0.9080 - val_loss: 0.2783
# Epoch 45/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9460 - loss: 0.1803 - val_accuracy: 0.9100 - val_loss: 0.2759
# Epoch 46/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9460 - loss: 0.1795 - val_accuracy: 0.9080 - val_loss: 0.2784
# Epoch 47/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9460 - loss: 0.1785 - val_accuracy: 0.9120 - val_loss: 0.2782
# Epoch 48/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9460 - loss: 0.1780 - val_accuracy: 0.9080 - val_loss: 0.2755
# Epoch 49/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9480 - loss: 0.1773 - val_accuracy: 0.9100 - val_loss: 0.2790
# Epoch 50/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9460 - loss: 0.1770 - val_accuracy: 0.9100 - val_loss: 0.2758
# Epoch 51/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9480 - loss: 0.1761 - val_accuracy: 0.9100 - val_loss: 0.2777
# Epoch 52/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9460 - loss: 0.1755 - val_accuracy: 0.9100 - val_loss: 0.2758
# Epoch 53/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9480 - loss: 0.1752 - val_accuracy: 0.9100 - val_loss: 0.2771
# Epoch 54/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9460 - loss: 0.1747 - val_accuracy: 0.9100 - val_loss: 0.2774
# Epoch 55/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9480 - loss: 0.1744 - val_accuracy: 0.9100 - val_loss: 0.2760
# Epoch 56/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9480 - loss: 0.1740 - val_accuracy: 0.9100 - val_loss: 0.2775
# Epoch 57/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9480 - loss: 0.1738 - val_accuracy: 0.9100 - val_loss: 0.2760
# Epoch 58/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9460 - loss: 0.1733 - val_accuracy: 0.9100 - val_loss: 0.2769
# Epoch 59/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9480 - loss: 0.1731 - val_accuracy: 0.9100 - val_loss: 0.2769
# Epoch 60/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9480 - loss: 0.1728 - val_accuracy: 0.9100 - val_loss: 0.2764
# Epoch 61/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9480 - loss: 0.1727 - val_accuracy: 0.9100 - val_loss: 0.2769
# Epoch 62/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9480 - loss: 0.1725 - val_accuracy: 0.9100 - val_loss: 0.2762
# Epoch 63/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9480 - loss: 0.1722 - val_accuracy: 0.9100 - val_loss: 0.2768
# Epoch 64/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9480 - loss: 0.1723 - val_accuracy: 0.9100 - val_loss: 0.2767
# Epoch 65/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9480 - loss: 0.1721 - val_accuracy: 0.9100 - val_loss: 0.2768
# Epoch 66/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9480 - loss: 0.1720 - val_accuracy: 0.9100 - val_loss: 0.2767
# Epoch 67/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9480 - loss: 0.1721 - val_accuracy: 0.9100 - val_loss: 0.2772
# Epoch 68/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9480 - loss: 0.1719 - val_accuracy: 0.9100 - val_loss: 0.2768
# Epoch 69/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9480 - loss: 0.1721 - val_accuracy: 0.9100 - val_loss: 0.2768
# Epoch 70/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9480 - loss: 0.1720 - val_accuracy: 0.9100 - val_loss: 0.2768
# Epoch 71/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9480 - loss: 0.1720 - val_accuracy: 0.9100 - val_loss: 0.2777
# Epoch 72/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9480 - loss: 0.1719 - val_accuracy: 0.9120 - val_loss: 0.2773
# Epoch 73/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9480 - loss: 0.1721 - val_accuracy: 0.9100 - val_loss: 0.2786
# Epoch 74/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9480 - loss: 0.1721 - val_accuracy: 0.9120 - val_loss: 0.2755
# Epoch 75/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9480 - loss: 0.1723 - val_accuracy: 0.9100 - val_loss: 0.2792
# Epoch 76/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9480 - loss: 0.1724 - val_accuracy: 0.9100 - val_loss: 0.2767
# Epoch 77/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9480 - loss: 0.1726 - val_accuracy: 0.9100 - val_loss: 0.2802
# Epoch 78/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9460 - loss: 0.1727 - val_accuracy: 0.9100 - val_loss: 0.2780
# Epoch 79/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9480 - loss: 0.1728 - val_accuracy: 0.9120 - val_loss: 0.2812
# Epoch 80/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9440 - loss: 0.1726 - val_accuracy: 0.9100 - val_loss: 0.2765
# Epoch 81/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9480 - loss: 0.1726 - val_accuracy: 0.9100 - val_loss: 0.2822
# Epoch 82/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9460 - loss: 0.1726 - val_accuracy: 0.9100 - val_loss: 0.2776
# Epoch 83/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9460 - loss: 0.1725 - val_accuracy: 0.9100 - val_loss: 0.2809
# Epoch 84/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9460 - loss: 0.1737 - val_accuracy: 0.9080 - val_loss: 0.2840
# Epoch 85/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9460 - loss: 0.1759 - val_accuracy: 0.9100 - val_loss: 0.2796
# Epoch 86/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9480 - loss: 0.1757 - val_accuracy: 0.9080 - val_loss: 0.2826
# Epoch 87/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9460 - loss: 0.1758 - val_accuracy: 0.9100 - val_loss: 0.2852
# Epoch 88/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9440 - loss: 0.1775 - val_accuracy: 0.9080 - val_loss: 0.2831
# Epoch 89/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9440 - loss: 0.1778 - val_accuracy: 0.9100 - val_loss: 0.2838
# Epoch 90/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9420 - loss: 0.1762 - val_accuracy: 0.9100 - val_loss: 0.2816
# Epoch 91/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9420 - loss: 0.1760 - val_accuracy: 0.9080 - val_loss: 0.2871
# Epoch 92/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9400 - loss: 0.1784 - val_accuracy: 0.9080 - val_loss: 0.2823
# Epoch 93/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9340 - loss: 0.1851 - val_accuracy: 0.9060 - val_loss: 0.2894
# Epoch 94/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9400 - loss: 0.1775 - val_accuracy: 0.9020 - val_loss: 0.2959
# Epoch 95/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9400 - loss: 0.1847 - val_accuracy: 0.9120 - val_loss: 0.2713
# Epoch 96/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9380 - loss: 0.1808 - val_accuracy: 0.9140 - val_loss: 0.2749
# Epoch 97/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9400 - loss: 0.1755 - val_accuracy: 0.9060 - val_loss: 0.2877
# Epoch 98/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9400 - loss: 0.1757 - val_accuracy: 0.9100 - val_loss: 0.2889
# Epoch 99/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9400 - loss: 0.1787 - val_accuracy: 0.9040 - val_loss: 0.2865
# Epoch 100/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9380 - loss: 0.1866 - val_accuracy: 0.9180 - val_loss: 0.2725

# %%
print(f"Best score: {best_history.history['val_accuracy'][-1]:.4f}")
# Out:
# Best score: 0.9180

# %% [markdown]
# #### Without learning rate scheduler

# %%
optimizer_no_lr = Adam()

model_no_lr = best_model

model_no_lr.compile(
        optimizer=optimizer,
        loss='binary_crossentropy',
        metrics=['accuracy']
)

history_no_lr= model_no_lr.fit(
    X_train, y_train,
    epochs=best_params['epochs'],
    batch_size=32,
    validation_data=(X_test, y_test)
)
# Out:
# Epoch 1/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9340 - loss: 0.1891 - val_accuracy: 0.9080 - val_loss: 0.2913
# Epoch 2/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9400 - loss: 0.1776 - val_accuracy: 0.9040 - val_loss: 0.2959
# Epoch 3/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9380 - loss: 0.1888 - val_accuracy: 0.9100 - val_loss: 0.2889
# Epoch 4/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9400 - loss: 0.1824 - val_accuracy: 0.9040 - val_loss: 0.3004
# Epoch 5/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9420 - loss: 0.1806 - val_accuracy: 0.9200 - val_loss: 0.2741
# Epoch 6/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9340 - loss: 0.1865 - val_accuracy: 0.9060 - val_loss: 0.2852
# Epoch 7/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9440 - loss: 0.1773 - val_accuracy: 0.9060 - val_loss: 0.3010
# Epoch 8/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9400 - loss: 0.1832 - val_accuracy: 0.9140 - val_loss: 0.2880
# Epoch 9/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9400 - loss: 0.1832 - val_accuracy: 0.8940 - val_loss: 0.2963
# Epoch 10/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9380 - loss: 0.1932 - val_accuracy: 0.9160 - val_loss: 0.2707
# Epoch 11/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9380 - loss: 0.1923 - val_accuracy: 0.9040 - val_loss: 0.3018
# Epoch 12/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9380 - loss: 0.1808 - val_accuracy: 0.9020 - val_loss: 0.2958
# Epoch 13/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9420 - loss: 0.1815 - val_accuracy: 0.9160 - val_loss: 0.2825
# Epoch 14/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9420 - loss: 0.1801 - val_accuracy: 0.9040 - val_loss: 0.3053
# Epoch 15/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9460 - loss: 0.1822 - val_accuracy: 0.9260 - val_loss: 0.2730
# Epoch 16/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9360 - loss: 0.1862 - val_accuracy: 0.9120 - val_loss: 0.2917
# Epoch 17/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9420 - loss: 0.1743 - val_accuracy: 0.9020 - val_loss: 0.2974
# Epoch 18/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9460 - loss: 0.1800 - val_accuracy: 0.9180 - val_loss: 0.2794
# Epoch 19/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9380 - loss: 0.1766 - val_accuracy: 0.9080 - val_loss: 0.3084
# Epoch 20/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9440 - loss: 0.1776 - val_accuracy: 0.9180 - val_loss: 0.2777
# Epoch 21/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9420 - loss: 0.1741 - val_accuracy: 0.9120 - val_loss: 0.3083
# Epoch 22/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9380 - loss: 0.1762 - val_accuracy: 0.9260 - val_loss: 0.2736
# Epoch 23/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9380 - loss: 0.1769 - val_accuracy: 0.9180 - val_loss: 0.2785
# Epoch 24/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9420 - loss: 0.1693 - val_accuracy: 0.9080 - val_loss: 0.2865
# Epoch 25/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9460 - loss: 0.1752 - val_accuracy: 0.9180 - val_loss: 0.2839
# Epoch 26/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9440 - loss: 0.1727 - val_accuracy: 0.9220 - val_loss: 0.2782
# Epoch 27/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9420 - loss: 0.1661 - val_accuracy: 0.9140 - val_loss: 0.2763
# Epoch 28/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9460 - loss: 0.1663 - val_accuracy: 0.9180 - val_loss: 0.2733
# Epoch 29/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9460 - loss: 0.1638 - val_accuracy: 0.9160 - val_loss: 0.2752
# Epoch 30/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9480 - loss: 0.1625 - val_accuracy: 0.9200 - val_loss: 0.2813
# Epoch 31/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9440 - loss: 0.1670 - val_accuracy: 0.9120 - val_loss: 0.2868
# Epoch 32/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9420 - loss: 0.1680 - val_accuracy: 0.9260 - val_loss: 0.2740
# Epoch 33/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9440 - loss: 0.1693 - val_accuracy: 0.9140 - val_loss: 0.2758
# Epoch 34/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9460 - loss: 0.1688 - val_accuracy: 0.9200 - val_loss: 0.2773
# Epoch 35/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9500 - loss: 0.1647 - val_accuracy: 0.9200 - val_loss: 0.2929
# Epoch 36/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9440 - loss: 0.1647 - val_accuracy: 0.9260 - val_loss: 0.2739
# Epoch 37/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9480 - loss: 0.1629 - val_accuracy: 0.9200 - val_loss: 0.2902
# Epoch 38/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9380 - loss: 0.1692 - val_accuracy: 0.9280 - val_loss: 0.2767
# Epoch 39/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9460 - loss: 0.1631 - val_accuracy: 0.9160 - val_loss: 0.2964
# Epoch 40/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9460 - loss: 0.1707 - val_accuracy: 0.9260 - val_loss: 0.2922
# Epoch 41/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9460 - loss: 0.1683 - val_accuracy: 0.9200 - val_loss: 0.2828
# Epoch 42/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9380 - loss: 0.1760 - val_accuracy: 0.9260 - val_loss: 0.2790
# Epoch 43/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9420 - loss: 0.1681 - val_accuracy: 0.9220 - val_loss: 0.3014
# Epoch 44/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9380 - loss: 0.1704 - val_accuracy: 0.9220 - val_loss: 0.2778
# Epoch 45/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9480 - loss: 0.1614 - val_accuracy: 0.9200 - val_loss: 0.2969
# Epoch 46/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9380 - loss: 0.1726 - val_accuracy: 0.9220 - val_loss: 0.2936
# Epoch 47/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9440 - loss: 0.1668 - val_accuracy: 0.9240 - val_loss: 0.2927
# Epoch 48/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9420 - loss: 0.1739 - val_accuracy: 0.9180 - val_loss: 0.3036
# Epoch 49/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9520 - loss: 0.1610 - val_accuracy: 0.9240 - val_loss: 0.2888
# Epoch 50/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9460 - loss: 0.1614 - val_accuracy: 0.9200 - val_loss: 0.3043
# Epoch 51/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9500 - loss: 0.1567 - val_accuracy: 0.9280 - val_loss: 0.2773
# Epoch 52/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9500 - loss: 0.1510 - val_accuracy: 0.9260 - val_loss: 0.2804
# Epoch 53/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9500 - loss: 0.1504 - val_accuracy: 0.9240 - val_loss: 0.2842
# Epoch 54/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9500 - loss: 0.1469 - val_accuracy: 0.9280 - val_loss: 0.2851
# Epoch 55/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9480 - loss: 0.1481 - val_accuracy: 0.9280 - val_loss: 0.2816
# Epoch 56/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9500 - loss: 0.1467 - val_accuracy: 0.9260 - val_loss: 0.2832
# Epoch 57/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9500 - loss: 0.1461 - val_accuracy: 0.9260 - val_loss: 0.2848
# Epoch 58/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9500 - loss: 0.1454 - val_accuracy: 0.9260 - val_loss: 0.2854
# Epoch 59/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9500 - loss: 0.1449 - val_accuracy: 0.9280 - val_loss: 0.2860
# Epoch 60/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9500 - loss: 0.1446 - val_accuracy: 0.9280 - val_loss: 0.2860
# Epoch 61/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9500 - loss: 0.1444 - val_accuracy: 0.9300 - val_loss: 0.2839
# Epoch 62/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9520 - loss: 0.1438 - val_accuracy: 0.9260 - val_loss: 0.2861
# Epoch 63/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9500 - loss: 0.1438 - val_accuracy: 0.9300 - val_loss: 0.2841
# Epoch 64/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9520 - loss: 0.1439 - val_accuracy: 0.9260 - val_loss: 0.2843
# Epoch 65/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9500 - loss: 0.1430 - val_accuracy: 0.9280 - val_loss: 0.2855
# Epoch 66/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9500 - loss: 0.1429 - val_accuracy: 0.9280 - val_loss: 0.2854
# Epoch 67/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9500 - loss: 0.1426 - val_accuracy: 0.9280 - val_loss: 0.2869
# Epoch 68/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9500 - loss: 0.1422 - val_accuracy: 0.9280 - val_loss: 0.2875
# Epoch 69/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9500 - loss: 0.1417 - val_accuracy: 0.9300 - val_loss: 0.2868
# Epoch 70/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9500 - loss: 0.1417 - val_accuracy: 0.9280 - val_loss: 0.2869
# Epoch 71/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9500 - loss: 0.1412 - val_accuracy: 0.9300 - val_loss: 0.2869
# Epoch 72/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9520 - loss: 0.1411 - val_accuracy: 0.9300 - val_loss: 0.2868
# Epoch 73/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9520 - loss: 0.1411 - val_accuracy: 0.9300 - val_loss: 0.2869
# Epoch 74/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9500 - loss: 0.1412 - val_accuracy: 0.9300 - val_loss: 0.2870
# Epoch 75/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9500 - loss: 0.1410 - val_accuracy: 0.9280 - val_loss: 0.2872
# Epoch 76/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9500 - loss: 0.1409 - val_accuracy: 0.9280 - val_loss: 0.2878
# Epoch 77/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9500 - loss: 0.1407 - val_accuracy: 0.9300 - val_loss: 0.2874
# Epoch 78/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9520 - loss: 0.1408 - val_accuracy: 0.9300 - val_loss: 0.2875
# Epoch 79/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9500 - loss: 0.1408 - val_accuracy: 0.9280 - val_loss: 0.2882
# Epoch 80/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9500 - loss: 0.1408 - val_accuracy: 0.9300 - val_loss: 0.2884
# Epoch 81/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9500 - loss: 0.1408 - val_accuracy: 0.9280 - val_loss: 0.2888
# Epoch 82/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9500 - loss: 0.1413 - val_accuracy: 0.9300 - val_loss: 0.2864
# Epoch 83/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9520 - loss: 0.1419 - val_accuracy: 0.9260 - val_loss: 0.2875
# Epoch 84/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9520 - loss: 0.1412 - val_accuracy: 0.9280 - val_loss: 0.2898
# Epoch 85/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9500 - loss: 0.1414 - val_accuracy: 0.9300 - val_loss: 0.2865
# Epoch 86/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9520 - loss: 0.1415 - val_accuracy: 0.9260 - val_loss: 0.2907
# Epoch 87/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9500 - loss: 0.1422 - val_accuracy: 0.9300 - val_loss: 0.2862
# Epoch 88/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9520 - loss: 0.1436 - val_accuracy: 0.9280 - val_loss: 0.2864
# Epoch 89/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9520 - loss: 0.1423 - val_accuracy: 0.9240 - val_loss: 0.2900
# Epoch 90/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9500 - loss: 0.1427 - val_accuracy: 0.9240 - val_loss: 0.2903
# Epoch 91/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9520 - loss: 0.1439 - val_accuracy: 0.9260 - val_loss: 0.2875
# Epoch 92/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9500 - loss: 0.1442 - val_accuracy: 0.9260 - val_loss: 0.2900
# Epoch 93/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9500 - loss: 0.1434 - val_accuracy: 0.9280 - val_loss: 0.2902
# Epoch 94/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9520 - loss: 0.1434 - val_accuracy: 0.9260 - val_loss: 0.2908
# Epoch 95/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9480 - loss: 0.1459 - val_accuracy: 0.9240 - val_loss: 0.2866
# Epoch 96/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9520 - loss: 0.1461 - val_accuracy: 0.9240 - val_loss: 0.2888
# Epoch 97/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9500 - loss: 0.1454 - val_accuracy: 0.9260 - val_loss: 0.2857
# Epoch 98/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9520 - loss: 0.1465 - val_accuracy: 0.9240 - val_loss: 0.2929
# Epoch 99/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9500 - loss: 0.1468 - val_accuracy: 0.9200 - val_loss: 0.2974
# Epoch 100/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9520 - loss: 0.1503 - val_accuracy: 0.9300 - val_loss: 0.2861

# %%
print(f"Score with LR: {best_history.history['val_accuracy'][-1]:.4f}")
print(f"Score without LR: {history_no_lr.history['val_accuracy'][-1]:.4f}")
# Out:
# Score with LR: 0.9180
# Score without LR: 0.9300

# %% [markdown]
# #### Learning rate curve plot

# %%
steps = np.arange(0,best_params['model__total_steps'])


lr_to_plot = [lr_best(step) for step in steps]
plt.plot(steps, lr_to_plot)
plt.xlabel("Steps")
plt.ylabel("Learning Rate")
plt.show()

# %% [markdown]
# #### Discussion
# - **How can you make sure the results are reproducable?**
# We can try to make the results reproducable by setting a seed, to make the model more deteministic. I also added ```
# tf.config.experimental.enable_op_determinism()```. According to the tensforflow documentation for this function, this enables all tensorflow ops to be deterministic, meaning that if the model gets the same input, it produces the same output regardless of how many times it is ran.
#
# - **Which optimizer did you choose? Discuss the differences between SGD and Adam**
# I chose to go with the Adam optimizer, due to the optimizers adaptive learning rate. This and momentum is the difference between Adam and SGD. Adam takes momentum into account, it calculates the first momentum and, which is the moving average of the gradient. SGD can also use momentum, but SGD also has a fixed learning rate.

# %% [markdown]
# # 📶📡🛰️🤳 Mission 2.2: Locate the AI Servers
#
# ### 🌐 The Discovery
# The NTNU Intelligence team has intercepted encrypted documentation that potentially reveals the locations of AI-compromised servers within Trondheim. Our analysts believe the data contains information about these servers' locations.
#
# However, the number of servers and their exact positions remain unknown. To execute a strategic response, we need to understand the intercepted data and pinpoint the main AI servers.
#
# We have also discovered a vulnerability in the AI's security: it has deployed a clustering verification feature on Kaggle. We can exploit this backdoor to validate our clustering hypotheses.
#
# ### 🎯 Your Mission
# Identify the number of hidden servers (clusters) in the dataset. Assign cluster labels to each row in the original dataset and validate your clustering solution on Kaggle.  When achieved the perfect clustering accuracy, find the precise locations of these servers (clusters).
#
# ### 🧠 The Challenge
# 1. **Large Dataset**: The intercepted data file contains numerous features, making direct manipulation and clustering difficult. Applying dimensionality reduction techniques could help reveal patterns.
# 2. **Unsupervised Learning**: No target labels are provided, so you must identify patterns based solely on the dataset's features.
# 3. **Data Obfuscation**: The AI has obfuscated the data, making it difficult to discern its true structure. You must effectively manipulate the data to visually identify server locations.
#
#
# ### 🚀 Your Tools
# - The intercepted AI dataset.
# - Skills in feature engineering, data manipulation, and visualization.
# - Clustering algorithms (e.g., KMeans, DBSCAN, Birch, Agglomerative Clustering, etc.) — [Clustering in Scikit-Learn](https://scikit-learn.org/stable/modules/clustering.html)
# - Dimensionality reduction techniques (e.g., PCA, t-SNE, Isomap, UMAP, etc.)
# - Kaggle competition platform with a daily submission limit of 50 attempts.
#
# > Note: Kaggle competition link — [Kaggle Competition](https://www.kaggle.com/t/dfb72837bdb346449768b8f6ce50b6dc)
#
# ### 📊 Formal Requirements
# 1. **Achieve 100% Clustering Accuracy** on Kaggle.
# > Note: The only way to check whether your clustering is correct is to submit it to Kaggle. We do not give you the clusters directly.
#
# 2. **Discussion Questions**:
#    - **Dimensionality Reduction**: Which dimensionality reduction methods helped you determine the correct number of clusters? Why did some methods work better than others? Explain the differences between PCA, t-SNE, and UMAP.
#    - **Clustering Approach**: Which clustering algorithm and hyperparameters did you use? Discuss the differences between algorithms like KMeans and DBSCAN.
#    - **Data Type Analysis**: What is the hidden data type in the dataset? How does this information influence feature extraction for clustering? Can it explain why some dimensionality reduction algorithms are more effective?
#    - **Server Locations**: Identify the server locations. List the specific facilities in Trondheim and explain how you deduced their locations.
#    - **Advanced Task (Optional)**: Extract features using modern pre-trained neural networks for this data type. Apply dimensionality reduction and clustering algorithms to the extracted features.

# %%
# Hmmmmm, why is the first row skipped?
data = pd.read_csv('unsupervised_data.csv', skiprows=1, header=None)
# Get the ID column
data.reset_index(drop=False, inplace=True)
data.rename(columns={'index': 'ID'}, inplace=True)
data
# Out:
#         ID         0         1         2         3         4         5  \
# 0        0  0.314365  0.646305  0.323849  0.238492  0.655790  0.646305
# 1        1  0.587628  0.494976  0.559832 -0.246237  0.513506  0.550567
# 2        2  0.590203  0.367673  0.367673  0.367673  0.367673  0.590203
# 3        3  0.589296  0.589296  0.579825  0.551415  0.579825  0.579825
# 4        4  0.660095  0.470676  0.190366  0.672806  0.470761  0.672766
# ...    ...       ...       ...       ...       ...       ...       ...
# 3995  3995  0.340739  0.340739  0.340739  0.681823  0.340739  0.340739
# 3996  3996  0.384257  0.384257  0.675221  0.384257  0.384257  0.675221
# 3997  3997  0.641837  0.651135  0.251329  0.251329  0.651135  0.651135
# 3998  3998  0.555533  0.555533  0.555533  0.555533  0.555533  0.555533
# 3999  3999  0.592332  0.480734  0.144265  0.537585  0.262288  0.594780
#
#              6         7         8  ...     16374     16375     16376  \
# 0     0.646305  0.409205  0.646305  ...  0.646305  0.646305  0.655790
# 1     0.522772  0.596893  0.606158  ...  0.587628  0.550567  0.587628
# 2     0.367673  0.590203  0.590203  ...  0.590203  0.367673  0.590203
# 3     0.608236  0.579825  0.646118  ...  0.532474  0.523003  0.589296
# 4     0.672652  0.666151  0.672987  ...  0.432001  0.672222  0.190568
# ...        ...       ...       ...  ...       ...       ...       ...
# 3995  0.340739  0.672083  0.340739  ...  0.340739  0.662355  0.340739
# 3996  0.384257  0.675221  0.675221  ...  0.675221  0.384257  0.675221
# 3997  0.251329  0.651135  0.651135  ...  0.251329  0.251329  0.651135
# 3998  0.555533 -0.212897  0.555533  ...  0.555533  0.555533  0.555533
# 3999  0.542325  0.580735  0.594780  ...  0.594780  0.591386  0.594778
#
#          16377     16378     16379     16380     16381     16382     16383
# 0     0.238492  0.646305  0.674758  0.646305  0.238492  0.655790  0.646305
# 1     0.587628  0.550567  0.587628  0.550567  0.596893  0.494976  0.587628
# 2     0.590203  0.590203  0.590203  0.590203  0.590203  0.590203  0.476556
# 3     0.589296  0.551415  0.134721  0.475652  0.589296  0.570355  0.551415
# 4     0.217329  0.633684  0.673294  0.587914  0.671023  0.207578  0.470765
# ...        ...       ...       ...       ...       ...       ...       ...
# 3995  0.759779  0.331011  0.759779  0.340739  0.691563  0.340734  0.720789
# 3996  0.675221  0.675221  0.384257  0.384257  0.384257  0.675221  0.675221
# 3997  0.251329  0.409392  0.604646  0.651135  0.651135  0.660433  0.251329
# 3998  0.555533  0.555533  0.555533  0.555533  0.555533  0.555533  0.555533
# 3999  0.594795  0.132214  0.532101  0.298391  0.553934  0.594780  0.594794
#
# [4000 rows x 16385 columns]

# %%
# The dataset is heavy. Applying clustering directly on the dataset is likely not feasible. 
data.info(0)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Columns: 16385 entries, ID to 16383
# dtypes: float64(16384), int64(1)
# memory usage: 500.0 MB

# %%
# Features seem to be similarly distributed...
plt.hist(data.iloc[:, 2], bins=50, color='blue', alpha=0.5, label='Feature #2')
plt.hist(data.iloc[:, 13021], bins=50, color='red', alpha=0.5, label='Feature #13021')
plt.legend()
plt.show()

# %%
# To check your clustering, you need to assign the predicted cluster ids and submit it as a CSV file. The submission should be a CSV file with two columns: ID and cluster. 
# The ID column should contain the ID of the data point, and the cluster column should contain the cluster ID that the data point belongs to. 
# The cluster ID should be an integer. Current cluster IDs in sample_submission.csv are randomly generated.
sample_submission = pd.read_csv('sample_submission.csv')
sample_submission
# Out:
#         ID  cluster
# 0        0        2
# 1        1        6
# 2        2        3
# 3        3        3
# 4        4        8
# ...    ...      ...
# 3995  3995        3
# 3996  3996        7
# 3997  3997        3
# 3998  3998        7
# 3999  3999        2
#
# [4000 rows x 2 columns]

# %% [markdown]
# ---
#
# ## 🎯 Note: Clustering Accuracy Evaluation
#
# The clustering accuracy metric evaluates how well the predicted clusters match the true clusters, irrespective of the specific labels or names assigned to the clusters.
#
# This means that the evaluation is solely based on the correct grouping of data points rather than the numerical labels of the clusters themselves.
#
# ## Key Characteristics
#
# - **Name-Independent**: The metric cares only about how well the data points are grouped together, not the specific numerical or categorical labels used for the clusters.
# - **Focus on Grouping**: The evaluation rewards cluster assignments that correctly group the same data points together, regardless of the specific labels assigned.
#
# ### Example
#
# If the true cluster assignments are:
#
# ```
# [0, 0, 0, 1, 1, 1]
# ```
#
# and your predicted cluster assignments are:
#
# ```
# [1, 1, 1, 0, 0, 0]
# ```
#
# the accuracy will still be **1.0** because the grouping of points is identical, even though the numerical labels are swapped.
#
# ## How the Metric is Computed
#
# 1. **Contingency Matrix**:
#    - Construct a contingency matrix that represents the overlap between the true clusters and the predicted clusters.
#
# 2. **Optimal Correspondence**:
#    - Use an optimization algorithm, such as the Hungarian method (linear sum assignment), to find the best possible correspondence between true and predicted labels, maximizing the number of correctly assigned data points.
#
# 3. **Accuracy Calculation**:
#    - Calculate the accuracy as the ratio of correctly matched data points to the total number of data points.
#
# > This approach ensures that the evaluation is based on **cluster completeness** and **homogeneity**, rewarding cluster assignments that correctly group the same data points together, regardless of the specific labels used.
#
# ---

# %%
import numpy as np
import scipy.optimize
import sklearn.metrics

def calculate_clustering_accuracy(true_labels: np.ndarray, cluster_labels: np.ndarray) -> float:
    """
    Calculate the clustering accuracy between true labels and cluster labels.

    The function constructs a contingency matrix between the true labels and cluster labels.
    It then uses the Hungarian algorithm (also known as linear sum assignment) to find the
    best matching between the cluster labels and true labels. The clustering accuracy is 
    calculated as the number of correctly matched labels divided by the total number of labels.

    Args:
        true_labels (np.ndarray): An array of true labels for each data point.
        cluster_labels (np.ndarray): An array of cluster labels predicted by a clustering algorithm.

    Returns:
        float: The clustering accuracy, a value between 0 and 1 representing the proportion of 
               correctly matched labels.
    
    Example:
        >>> true_labels = np.array([0, 1, 2, 0, 1, 2])
        >>> cluster_labels = np.array([1, 2, 0, 1, 2, 0])
        >>> calculate_clustering_accuracy(true_labels, cluster_labels)
        1.0

    Raises:
        ValueError: If true_labels and cluster_labels are not of the same length.
    """
    # Check if the input labels are of the same length
    if true_labels.size != cluster_labels.size:
        raise ValueError("true_labels and cluster_labels must have the same length.")

    # Construct a contingency matrix where each cell [i, j] indicates the number of points with 
    # true label i and cluster label j.
    contingency_matrix = sklearn.metrics.cluster.contingency_matrix(true_labels, cluster_labels)
    
    # Find the best matching between true labels and cluster labels using the Hungarian algorithm.
    # We negate the contingency matrix because linear_sum_assignment finds the minimum cost assignment.
    row_ind, col_ind = scipy.optimize.linear_sum_assignment(-contingency_matrix)
    
    # Calculate the number of correctly assigned labels according to the optimal matching.
    correct_pairs = contingency_matrix[row_ind, col_ind].sum()
    
    # Compute the clustering accuracy as the ratio of correctly matched labels to total labels.
    accuracy = correct_pairs / true_labels.size

    return accuracy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 2
#       1 import numpy as np
# ----> 2 import scipy.optimize
#       3 import sklearn.metrics
#       5 def calculate_clustering_accuracy(true_labels: np.ndarray, cluster_labels: np.ndarray) -> float:
#
# ModuleNotFoundError: No module named 'scipy'

# %%
true_labels = np.array([0, 1, 2, 0, 1, 2])
cluster_labels = np.array([1, 2, 0, 1, 2, 0])
calculate_clustering_accuracy(true_labels, cluster_labels)
# Out:
# np.float64(1.0)

# %%
true_labels = np.array([0, 0, 0, 0, 0, 0])
cluster_labels = np.array([1, 2, 0, 1, 2, 0])
calculate_clustering_accuracy(true_labels, cluster_labels)
# Out:
# np.float64(0.3333333333333333)

# %%
true_labels = np.array([1, 1, 1, 2, 2, 2])
cluster_labels = np.array([0, 0, 0, 0, 0, 0])
calculate_clustering_accuracy(true_labels, cluster_labels)
# Out:
# np.float64(0.5)
